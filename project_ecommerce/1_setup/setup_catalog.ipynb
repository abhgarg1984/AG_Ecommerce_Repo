# %%
# %sql
CREATE CATALOG IF NOT EXISTS test_ecommerce_project_catalog;

# %%
# %sql
USE catalog test_ecommerce_project_catalog;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql
SHOW DATABASES FROM test_ecommerce_project_catalog;

# %%
# %sql
# DROP CATALOG IF EXISTS ecommerce CASCADE;
